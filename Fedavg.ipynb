# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathulyan/Federated-Learning/blob/main/Fedavg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install syft==0.2.9
# Out:
# Collecting syft==0.2.9
#   Downloading syft-0.2.9-py3-none-any.whl (433 kB)
#      |████████████████████████████████| 433 kB 13.0 MB/s
# Collecting notebook==5.7.8
#   Downloading notebook-5.7.8-py2.py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 20.3 MB/s
# Requirement already satisfied: dill~=0.3.1 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.9) (0.3.4)
# Collecting websocket-client~=0.57.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 59.2 MB/s
# Collecting requests~=2.22.0
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.6 MB/s
# Collecting shaloop==0.2.1-alpha.11
#   Downloading shaloop-0.2.1_alpha.11-py3-none-manylinux1_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 56.8 MB/s
# Collecting flask-socketio~=4.2.1
#   Downloading Flask_SocketIO-4.2.1-py2.py3-none-any.whl (16 kB)
# Collecting psutil==5.7.0
#   Downloading psutil-5.7.0.tar.gz (449 kB)
#      |████████████████████████████████| 449 kB 45.7 MB/s
# Collecting importlib-resources~=1.5.0
#   Downloading importlib_resources-1.5.0-py2.py3-none-any.whl (21 kB)
# Collecting tornado==4.5.3
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      |████████████████████████████████| 484 kB 48.7 MB/s
# Collecting websockets~=8.1.0
#   Downloading websockets-8.1-cp37-cp37m-manylinux2010_x86_64.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.9 MB/s
# Collecting lz4~=3.0.2
#   Downloading lz4-3.0.2-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 45.3 MB/s
# Collecting tblib~=1.6.0
#   Downloading tblib-1.6.0-py2.py3-none-any.whl (12 kB)
# Collecting numpy~=1.18.1
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.3 MB/s
# Collecting requests-toolbelt==0.9.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.7 MB/s
# Requirement already satisfied: scipy~=1.4.1 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.9) (1.4.1)
# Collecting torchvision~=0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 42.2 MB/s
# Requirement already satisfied: Flask~=1.1.1 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.9) (1.1.4)
# Collecting RestrictedPython~=5.0
#   Downloading RestrictedPython-5.1-py2.py3-none-any.whl (27 kB)
# Collecting torch~=1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      |████████████████████████████████| 753.4 MB 6.1 kB/s
# Requirement already satisfied: msgpack~=1.0.0 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.9) (1.0.2)
# Collecting syft-proto~=0.5.2
#   Downloading syft_proto-0.5.3-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 4.3 MB/s
# Collecting openmined.threepio==0.2.0
#   Downloading openmined.threepio-0.2.0.tar.gz (73 kB)
#      |████████████████████████████████| 73 kB 2.2 MB/s
# Collecting phe~=1.4.0
#   Downloading phe-1.4.0.tar.gz (35 kB)
# Requirement already satisfied: Pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.9) (7.1.2)
# Collecting aiortc==0.9.28
#   Downloading aiortc-0.9.28-cp37-cp37m-manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 38.0 MB/s
# Collecting pyee>=6.0.0
#   Downloading pyee-8.1.0-py2.py3-none-any.whl (12 kB)
# Collecting av<9.0.0,>=8.0.0
#   Downloading av-8.0.3-cp37-cp37m-manylinux2010_x86_64.whl (37.2 MB)
#      |████████████████████████████████| 37.2 MB 31 kB/s
# Collecting crc32c
#   Downloading crc32c-2.2.post0-cp37-cp37m-manylinux2010_x86_64.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.6 MB/s
# Collecting aioice<0.7.0,>=0.6.17
#   Downloading aioice-0.6.18-py3-none-any.whl (19 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from aiortc==0.9.28->syft==0.2.9) (1.14.6)
# Collecting pylibsrtp>=0.5.6
#   Downloading pylibsrtp-0.6.8-cp37-cp37m-manylinux2010_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.8 MB/s
# Collecting cryptography>=2.2
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 58.4 MB/s
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.11.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (4.10.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.1.3)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.0.5)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.10.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.2.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.3.5)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (1.7.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (22.1.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook==5.7.8->syft==0.2.9) (4.7.1)
# Requirement already satisfied: pycparser>=2 in /usr/local/lib/python3.7/dist-packages (from shaloop==0.2.1-alpha.11->syft==0.2.9) (2.20)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.1->syft==0.2.9) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.1->syft==0.2.9) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.1->syft==0.2.9) (1.1.0)
# Collecting python-socketio>=4.3.0
#   Downloading python_socketio-5.3.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from importlib-resources~=1.5.0->syft==0.2.9) (4.6.1)
# Requirement already satisfied: zipp>=0.4 in /usr/local/lib/python3.7/dist-packages (from importlib-resources~=1.5.0->syft==0.2.9) (3.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook==5.7.8->syft==0.2.9) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook==5.7.8->syft==0.2.9) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client>=5.2.0->notebook==5.7.8->syft==0.2.9) (1.15.0)
# Collecting bidict>=0.21.0
#   Downloading bidict-0.21.2-py2.py3-none-any.whl (37 kB)
# Collecting python-engineio>=4.1.0
#   Downloading python_engineio-4.2.0-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 485 kB/s
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.4 MB/s
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.22.0->syft==0.2.9) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.22.0->syft==0.2.9) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.22.0->syft==0.2.9) (2021.5.30)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from syft-proto~=0.5.2->syft==0.2.9) (3.17.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook==5.7.8->syft==0.2.9) (0.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->importlib-resources~=1.5.0->syft==0.2.9) (3.7.4.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->notebook==5.7.8->syft==0.2.9) (5.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (57.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (1.0.18)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.2.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (3.3.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook==5.7.8->syft==0.2.9) (2.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook==5.7.8->syft==0.2.9) (21.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook==5.7.8->syft==0.2.9) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook==5.7.8->syft==0.2.9) (2.4.7)
# Building wheels for collected packages: openmined.threepio, psutil, tornado, phe
#   Building wheel for openmined.threepio (setup.py) ... done
#   Created wheel for openmined.threepio: filename=openmined.threepio-0.2.0-py3-none-any.whl size=80095 sha256=1be24d0e0792c0c961c4732dd5a59836b7c0706045e0d657baae1b4c7ca2ebc6
#   Stored in directory: /root/.cache/pip/wheels/97/3d/ce/4ca4386006e622cb87d5116e5e65026ec021d3cf906a9b3d5d
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.0-cp37-cp37m-linux_x86_64.whl size=276493 sha256=246bab765264a1220f06a787b38b2339d7eb3729d2fbcdae154c8828b537bf8e
#   Stored in directory: /root/.cache/pip/wheels/b6/e7/50/aee9cc966163d74430f13f208171dee22f11efa4a4a826661c
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-4.5.3-cp37-cp37m-linux_x86_64.whl size=434058 sha256=e747d3296db822ac327a26fc124acacb01aa49817490d10af2ca9df005216922
#   Stored in directory: /root/.cache/pip/wheels/a2/45/43/36ec7a893e16c1212a6b1505ded0a2d73cf8e863a0227c8e04
#   Building wheel for phe (setup.py) ... done
#   Created wheel for phe: filename=phe-1.4.0-py2.py3-none-any.whl size=37362 sha256=f29c25ceab35b2d4e6185a06616e1b62f003af13e49074f9993a47416c5d96a9
#   Stored in directory: /root/.cache/pip/wheels/bb/ac/9b/b07a04fe6bb1418ab4ee06d6652757aef848b80363c4dac507
# Successfully built openmined.threepio psutil tornado phe
# Installing collected packages: tornado, python-engineio, netifaces, idna, bidict, torch, requests, python-socketio, pylibsrtp, pyee, numpy, cryptography, crc32c, av, aioice, websockets, websocket-client, torchvision, tblib, syft-proto, shaloop, RestrictedPython, requests-toolbelt, psutil, phe, openmined.threepio, notebook, lz4, importlib-resources, flask-socketio, aiortc, syft
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu102
#     Uninstalling torchvision-0.10.0+cu102:
#       Successfully uninstalled torchvision-0.10.0+cu102
#   Attempting uninstall: tblib
#     Found existing installation: tblib 1.7.0
#     Uninstalling tblib-1.7.0:
#       Successfully uninstalled tblib-1.7.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.3.1
#     Uninstalling notebook-5.3.1:
#       Successfully uninstalled notebook-5.3.1
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.2.0
#     Uninstalling importlib-resources-5.2.0:
#       Successfully uninstalled importlib-resources-5.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.4.0 which is incompatible.
# tensorflow 2.5.0 requires numpy~=1.19.2, but you have numpy 1.18.5 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 5.7.8 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.22.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 4.5.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# bokeh 2.3.3 requires tornado>=5.1, but you have tornado 4.5.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed RestrictedPython-5.1 aioice-0.6.18 aiortc-0.9.28 av-8.0.3 bidict-0.21.2 crc32c-2.2.post0 cryptography-3.4.7 flask-socketio-4.2.1 idna-2.8 importlib-resources-1.5.0 lz4-3.0.2 netifaces-0.11.0 notebook-5.7.8 numpy-1.18.5 openmined.threepio-0.2.0 phe-1.4.0 psutil-5.7.0 pyee-8.1.0 pylibsrtp-0.6.8 python-engineio-4.2.0 python-socketio-5.3.0 requests-2.22.0 requests-toolbelt-0.9.1 shaloop-0.2.1a11 syft-0.2.9 syft-proto-0.5.3 tblib-1.6.0 torch-1.4.0 torchvision-0.5.0 tornado-4.5.3 websocket-client-0.57.0 websockets-8.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels

# %%
import sys 
sys.path.append("/content/drive/MyDrive/Colab Notebooks/Research Internship")

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
class Arguments():
    def __init__(self):
        self.images = 60000
        self.clients = 4
        self.rounds = 2
        self.epochs = 2
        self.local_batches = 64
        self.lr = 0.01
        self.C = 0.9
        self.drop_rate = 0.1
        self.torch_seed = 0
        self.log_interval = 10
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

# %%
# Download MNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz
# Out:
# --2021-07-23 11:41:07--  http://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Resolving www.di.ens.fr (www.di.ens.fr)... 129.199.99.14
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.di.ens.fr/~lelarge/MNIST.tar.gz [following]
# --2021-07-23 11:41:07--  https://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘MNIST.tar.gz’
#
# MNIST.tar.gz            [         <=>        ]  33.20M  17.1MB/s    in 1.9s
#
# 2021-07-23 11:41:10 (17.1 MB/s) - ‘MNIST.tar.gz’ saved [34813078]
#
# MNIST/
# MNIST/raw/
# MNIST/raw/train-labels-idx1-ubyte
# MNIST/raw/t10k-labels-idx1-ubyte.gz
# MNIST/raw/t10k-labels-idx1-ubyte
# MNIST/raw/t10k-images-idx3-ubyte.gz
# MNIST/raw/train-images-idx3-ubyte
# MNIST/raw/train-labels-idx1-ubyte.gz
# MNIST/raw/t10k-images-idx3-ubyte
# MNIST/raw/train-images-idx3-ubyte.gz
# MNIST/processed/
# MNIST/processed/training.pt
# MNIST/processed/test.pt

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./data/', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
    client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
            data = data.send(client['hook'])
            target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
                loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
    client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

for fed_round in range(args.rounds):
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
    
#     # Testing 
#     for client in active_clients:
#         test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
    global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global')
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())
        
if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# /usr/local/lib/python3.7/dist-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# Model client2 Train Epoch: 1 [0/15040 (0%)]	Loss: 2.330532
# Model client2 Train Epoch: 1 [640/15040 (4%)]	Loss: 2.275516
# Model client2 Train Epoch: 1 [1280/15040 (9%)]	Loss: 2.230711
# Model client2 Train Epoch: 1 [1920/15040 (13%)]	Loss: 2.202952
# Model client2 Train Epoch: 1 [2560/15040 (17%)]	Loss: 2.121741
# Model client2 Train Epoch: 1 [3200/15040 (21%)]	Loss: 2.063148
# Model client2 Train Epoch: 1 [3840/15040 (26%)]	Loss: 1.943400
# Model client2 Train Epoch: 1 [4480/15040 (30%)]	Loss: 1.870464
# Model client2 Train Epoch: 1 [5120/15040 (34%)]	Loss: 1.658538
# Model client2 Train Epoch: 1 [5760/15040 (38%)]	Loss: 1.437021
# Model client2 Train Epoch: 1 [6400/15040 (43%)]	Loss: 1.238859
# Model client2 Train Epoch: 1 [7040/15040 (47%)]	Loss: 1.051628
# Model client2 Train Epoch: 1 [7680/15040 (51%)]	Loss: 0.898915
# Model client2 Train Epoch: 1 [8320/15040 (55%)]	Loss: 0.770097
# Model client2 Train Epoch: 1 [8960/15040 (60%)]	Loss: 0.585956
# Model client2 Train Epoch: 1 [9600/15040 (64%)]	Loss: 0.666775
# Model client2 Train Epoch: 1 [10240/15040 (68%)]	Loss: 0.642423
# Model client2 Train Epoch: 1 [10880/15040 (72%)]	Loss: 0.688965
# Model client2 Train Epoch: 1 [11520/15040 (77%)]	Loss: 0.517627
# Model client2 Train Epoch: 1 [12160/15040 (81%)]	Loss: 0.461038
# Model client2 Train Epoch: 1 [12800/15040 (85%)]	Loss: 0.615686
# Model client2 Train Epoch: 1 [13440/15040 (89%)]	Loss: 0.542889
# Model client2 Train Epoch: 1 [14080/15040 (94%)]	Loss: 0.555335
# Model client2 Train Epoch: 1 [14720/15040 (98%)]	Loss: 0.443081
# Model client2 Train Epoch: 2 [0/15040 (0%)]	Loss: 0.523400
# Model client2 Train Epoch: 2 [640/15040 (4%)]	Loss: 0.425393
# Model client2 Train Epoch: 2 [1280/15040 (9%)]	Loss: 0.601569
# Model client2 Train Epoch: 2 [1920/15040 (13%)]	Loss: 0.384849
# Model client2 Train Epoch: 2 [2560/15040 (17%)]	Loss: 0.295620
# Model client2 Train Epoch: 2 [3200/15040 (21%)]	Loss: 0.448525
# Model client2 Train Epoch: 2 [3840/15040 (26%)]	Loss: 0.342253
# Model client2 Train Epoch: 2 [4480/15040 (30%)]	Loss: 0.430133
# Model client2 Train Epoch: 2 [5120/15040 (34%)]	Loss: 0.296164
# Model client2 Train Epoch: 2 [5760/15040 (38%)]	Loss: 0.271415
# Model client2 Train Epoch: 2 [6400/15040 (43%)]	Loss: 0.332621
# Model client2 Train Epoch: 2 [7040/15040 (47%)]	Loss: 0.296771
# Model client2 Train Epoch: 2 [7680/15040 (51%)]	Loss: 0.365506
# Model client2 Train Epoch: 2 [8320/15040 (55%)]	Loss: 0.347692
# Model client2 Train Epoch: 2 [8960/15040 (60%)]	Loss: 0.397451
# Model client2 Train Epoch: 2 [9600/15040 (64%)]	Loss: 0.403888
# Model client2 Train Epoch: 2 [10240/15040 (68%)]	Loss: 0.243771
# Model client2 Train Epoch: 2 [10880/15040 (72%)]	Loss: 0.295784
# Model client2 Train Epoch: 2 [11520/15040 (77%)]	Loss: 0.344322
# Model client2 Train Epoch: 2 [12160/15040 (81%)]	Loss: 0.225246
# Model client2 Train Epoch: 2 [12800/15040 (85%)]	Loss: 0.150201
# Model client2 Train Epoch: 2 [13440/15040 (89%)]	Loss: 0.159793
# Model client2 Train Epoch: 2 [14080/15040 (94%)]	Loss: 0.486960
# Model client2 Train Epoch: 2 [14720/15040 (98%)]	Loss: 0.248423
# Model client4 Train Epoch: 1 [0/15040 (0%)]	Loss: 2.329407
# Model client4 Train Epoch: 1 [640/15040 (4%)]	Loss: 2.254324
# Model client4 Train Epoch: 1 [1280/15040 (9%)]	Loss: 2.233744
# Model client4 Train Epoch: 1 [1920/15040 (13%)]	Loss: 2.182421
# Model client4 Train Epoch: 1 [2560/15040 (17%)]	Loss: 2.120304
# Model client4 Train Epoch: 1 [3200/15040 (21%)]	Loss: 2.062895
# Model client4 Train Epoch: 1 [3840/15040 (26%)]	Loss: 1.931722
# Model client4 Train Epoch: 1 [4480/15040 (30%)]	Loss: 1.848232
# Model client4 Train Epoch: 1 [5120/15040 (34%)]	Loss: 1.651943
# Model client4 Train Epoch: 1 [5760/15040 (38%)]	Loss: 1.432232
# Model client4 Train Epoch: 1 [6400/15040 (43%)]	Loss: 1.255449
# Model client4 Train Epoch: 1 [7040/15040 (47%)]	Loss: 0.967368
# Model client4 Train Epoch: 1 [7680/15040 (51%)]	Loss: 0.910506
# Model client4 Train Epoch: 1 [8320/15040 (55%)]	Loss: 0.629513
# Model client4 Train Epoch: 1 [8960/15040 (60%)]	Loss: 0.921903
# Model client4 Train Epoch: 1 [9600/15040 (64%)]	Loss: 0.691076
# Model client4 Train Epoch: 1 [10240/15040 (68%)]	Loss: 0.481462
# Model client4 Train Epoch: 1 [10880/15040 (72%)]	Loss: 0.639405
# Model client4 Train Epoch: 1 [11520/15040 (77%)]	Loss: 0.583817
# Model client4 Train Epoch: 1 [12160/15040 (81%)]	Loss: 0.525327
# Model client4 Train Epoch: 1 [12800/15040 (85%)]	Loss: 0.624925
# Model client4 Train Epoch: 1 [13440/15040 (89%)]	Loss: 0.468242
# Model client4 Train Epoch: 1 [14080/15040 (94%)]	Loss: 0.467510
# Model client4 Train Epoch: 1 [14720/15040 (98%)]	Loss: 0.347012
# Model client4 Train Epoch: 2 [0/15040 (0%)]	Loss: 0.656058
# Model client4 Train Epoch: 2 [640/15040 (4%)]	Loss: 0.325891
# Model client4 Train Epoch: 2 [1280/15040 (9%)]	Loss: 0.326854
# Model client4 Train Epoch: 2 [1920/15040 (13%)]	Loss: 0.197296
# Model client4 Train Epoch: 2 [2560/15040 (17%)]	Loss: 0.495893
# Model client4 Train Epoch: 2 [3200/15040 (21%)]	Loss: 0.278935
# Model client4 Train Epoch: 2 [3840/15040 (26%)]	Loss: 0.347648
# Model client4 Train Epoch: 2 [4480/15040 (30%)]	Loss: 0.371305
# Model client4 Train Epoch: 2 [5120/15040 (34%)]	Loss: 0.377087
# Model client4 Train Epoch: 2 [5760/15040 (38%)]	Loss: 0.370665
# Model client4 Train Epoch: 2 [6400/15040 (43%)]	Loss: 0.199588
# Model client4 Train Epoch: 2 [7040/15040 (47%)]	Loss: 0.416887
# Model client4 Train Epoch: 2 [7680/15040 (51%)]	Loss: 0.272055
# Model client4 Train Epoch: 2 [8320/15040 (55%)]	Loss: 0.401785
# Model client4 Train Epoch: 2 [8960/15040 (60%)]	Loss: 0.377426
# Model client4 Train Epoch: 2 [9600/15040 (64%)]	Loss: 0.353626
# Model client4 Train Epoch: 2 [10240/15040 (68%)]	Loss: 0.515544
# Model client4 Train Epoch: 2 [10880/15040 (72%)]	Loss: 0.411279
# Model client4 Train Epoch: 2 [11520/15040 (77%)]	Loss: 0.289956
# Model client4 Train Epoch: 2 [12160/15040 (81%)]	Loss: 0.402432
# Model client4 Train Epoch: 2 [12800/15040 (85%)]	Loss: 0.236228
# Model client4 Train Epoch: 2 [13440/15040 (89%)]	Loss: 0.424012
# Model client4 Train Epoch: 2 [14080/15040 (94%)]	Loss: 0.346977
# Model client4 Train Epoch: 2 [14720/15040 (98%)]	Loss: 0.255506
#
# Test set: Average loss for Global model: 1.8698, Accuracy: 9208/10000 (92%)
#
# Model client4 Train Epoch: 1 [0/15040 (0%)]	Loss: 1.898673
# Model client4 Train Epoch: 1 [640/15040 (4%)]	Loss: 1.739378
# Model client4 Train Epoch: 1 [1280/15040 (9%)]	Loss: 1.568907
# Model client4 Train Epoch: 1 [1920/15040 (13%)]	Loss: 1.357378
# Model client4 Train Epoch: 1 [2560/15040 (17%)]	Loss: 1.142408
# Model client4 Train Epoch: 1 [3200/15040 (21%)]	Loss: 1.011527
# Model client4 Train Epoch: 1 [3840/15040 (26%)]	Loss: 0.677892
# Model client4 Train Epoch: 1 [4480/15040 (30%)]	Loss: 0.708669
# Model client4 Train Epoch: 1 [5120/15040 (34%)]	Loss: 0.502873
# Model client4 Train Epoch: 1 [5760/15040 (38%)]	Loss: 0.549355
# Model client4 Train Epoch: 1 [6400/15040 (43%)]	Loss: 0.597276
# Model client4 Train Epoch: 1 [7040/15040 (47%)]	Loss: 0.474776
# Model client4 Train Epoch: 1 [7680/15040 (51%)]	Loss: 0.472010
# Model client4 Train Epoch: 1 [8320/15040 (55%)]	Loss: 0.329331
# Model client4 Train Epoch: 1 [8960/15040 (60%)]	Loss: 0.423686
# Model client4 Train Epoch: 1 [9600/15040 (64%)]	Loss: 0.357879
# Model client4 Train Epoch: 1 [10240/15040 (68%)]	Loss: 0.248936
# Model client4 Train Epoch: 1 [10880/15040 (72%)]	Loss: 0.426039
# Model client4 Train Epoch: 1 [11520/15040 (77%)]	Loss: 0.391081
# Model client4 Train Epoch: 1 [12160/15040 (81%)]	Loss: 0.305967
# Model client4 Train Epoch: 1 [12800/15040 (85%)]	Loss: 0.294475
# Model client4 Train Epoch: 1 [13440/15040 (89%)]	Loss: 0.224500
# Model client4 Train Epoch: 1 [14080/15040 (94%)]	Loss: 0.303375
# Model client4 Train Epoch: 1 [14720/15040 (98%)]	Loss: 0.336273
# Model client4 Train Epoch: 2 [0/15040 (0%)]	Loss: 0.384069
# Model client4 Train Epoch: 2 [640/15040 (4%)]	Loss: 0.286666
# Model client4 Train Epoch: 2 [1280/15040 (9%)]	Loss: 0.374163
# Model client4 Train Epoch: 2 [1920/15040 (13%)]	Loss: 0.357373
# Model client4 Train Epoch: 2 [2560/15040 (17%)]	Loss: 0.424789
# Model client4 Train Epoch: 2 [3200/15040 (21%)]	Loss: 0.220485
# Model client4 Train Epoch: 2 [3840/15040 (26%)]	Loss: 0.217053
# Model client4 Train Epoch: 2 [4480/15040 (30%)]	Loss: 0.284793
# Model client4 Train Epoch: 2 [5120/15040 (34%)]	Loss: 0.246578
# Model client4 Train Epoch: 2 [5760/15040 (38%)]	Loss: 0.171062
# Model client4 Train Epoch: 2 [6400/15040 (43%)]	Loss: 0.428280
# Model client4 Train Epoch: 2 [7040/15040 (47%)]	Loss: 0.238121
# Model client4 Train Epoch: 2 [7680/15040 (51%)]	Loss: 0.305105
# Model client4 Train Epoch: 2 [8320/15040 (55%)]	Loss: 0.221702
# Model client4 Train Epoch: 2 [8960/15040 (60%)]	Loss: 0.156974
# Model client4 Train Epoch: 2 [9600/15040 (64%)]	Loss: 0.183858
# Model client4 Train Epoch: 2 [10240/15040 (68%)]	Loss: 0.292921
# Model client4 Train Epoch: 2 [10880/15040 (72%)]	Loss: 0.151463
# Model client4 Train Epoch: 2 [11520/15040 (77%)]	Loss: 0.203476
# Model client4 Train Epoch: 2 [12160/15040 (81%)]	Loss: 0.323628
# Model client4 Train Epoch: 2 [12800/15040 (85%)]	Loss: 0.208247
# Model client4 Train Epoch: 2 [13440/15040 (89%)]	Loss: 0.290463
# Model client4 Train Epoch: 2 [14080/15040 (94%)]	Loss: 0.295875
# Model client4 Train Epoch: 2 [14720/15040 (98%)]	Loss: 0.200673
# Model client1 Train Epoch: 1 [0/15040 (0%)]	Loss: 1.888958
# Model client1 Train Epoch: 1 [640/15040 (4%)]	Loss: 1.731414
# Model client1 Train Epoch: 1 [1280/15040 (9%)]	Loss: 1.590409
# Model client1 Train Epoch: 1 [1920/15040 (13%)]	Loss: 1.259891
# Model client1 Train Epoch: 1 [2560/15040 (17%)]	Loss: 1.099910
# Model client1 Train Epoch: 1 [3200/15040 (21%)]	Loss: 0.980365
# Model client1 Train Epoch: 1 [3840/15040 (26%)]	Loss: 0.735250
# Model client1 Train Epoch: 1 [4480/15040 (30%)]	Loss: 0.602287
# Model client1 Train Epoch: 1 [5120/15040 (34%)]	Loss: 0.579924
# Model client1 Train Epoch: 1 [5760/15040 (38%)]	Loss: 0.474794
# Model client1 Train Epoch: 1 [6400/15040 (43%)]	Loss: 0.481175
# Model client1 Train Epoch: 1 [7040/15040 (47%)]	Loss: 0.384161
# Model client1 Train Epoch: 1 [7680/15040 (51%)]	Loss: 0.542367
# Model client1 Train Epoch: 1 [8320/15040 (55%)]	Loss: 0.323658
# Model client1 Train Epoch: 1 [8960/15040 (60%)]	Loss: 0.380436
# Model client1 Train Epoch: 1 [9600/15040 (64%)]	Loss: 0.286025
# Model client1 Train Epoch: 1 [10240/15040 (68%)]	Loss: 0.510393
# Model client1 Train Epoch: 1 [10880/15040 (72%)]	Loss: 0.420188
# Model client1 Train Epoch: 1 [11520/15040 (77%)]	Loss: 0.469602
# Model client1 Train Epoch: 1 [12160/15040 (81%)]	Loss: 0.569832
# Model client1 Train Epoch: 1 [12800/15040 (85%)]	Loss: 0.399786
# Model client1 Train Epoch: 1 [13440/15040 (89%)]	Loss: 0.245351
# Model client1 Train Epoch: 1 [14080/15040 (94%)]	Loss: 0.351222
# Model client1 Train Epoch: 1 [14720/15040 (98%)]	Loss: 0.313241
# Model client1 Train Epoch: 2 [0/15040 (0%)]	Loss: 0.313565
# Model client1 Train Epoch: 2 [640/15040 (4%)]	Loss: 0.503389
# Model client1 Train Epoch: 2 [1280/15040 (9%)]	Loss: 0.400891
# Model client1 Train Epoch: 2 [1920/15040 (13%)]	Loss: 0.512842
# Model client1 Train Epoch: 2 [2560/15040 (17%)]	Loss: 0.298973
# Model client1 Train Epoch: 2 [3200/15040 (21%)]	Loss: 0.159471
# Model client1 Train Epoch: 2 [3840/15040 (26%)]	Loss: 0.356618
# Model client1 Train Epoch: 2 [4480/15040 (30%)]	Loss: 0.528429
# Model client1 Train Epoch: 2 [5120/15040 (34%)]	Loss: 0.463265
# Model client1 Train Epoch: 2 [5760/15040 (38%)]	Loss: 0.364905
# Model client1 Train Epoch: 2 [6400/15040 (43%)]	Loss: 0.256593
# Model client1 Train Epoch: 2 [7040/15040 (47%)]	Loss: 0.340070
# Model client1 Train Epoch: 2 [7680/15040 (51%)]	Loss: 0.220557
# Model client1 Train Epoch: 2 [8320/15040 (55%)]	Loss: 0.182076
# Model client1 Train Epoch: 2 [8960/15040 (60%)]	Loss: 0.440059
# Model client1 Train Epoch: 2 [9600/15040 (64%)]	Loss: 0.277270
# Model client1 Train Epoch: 2 [10240/15040 (68%)]	Loss: 0.556513
# Model client1 Train Epoch: 2 [10880/15040 (72%)]	Loss: 0.180395
# Model client1 Train Epoch: 2 [11520/15040 (77%)]	Loss: 0.280326
# Model client1 Train Epoch: 2 [12160/15040 (81%)]	Loss: 0.218773
# Model client1 Train Epoch: 2 [12800/15040 (85%)]	Loss: 0.373561
# Model client1 Train Epoch: 2 [13440/15040 (89%)]	Loss: 0.180875
# Model client1 Train Epoch: 2 [14080/15040 (94%)]	Loss: 0.268069
# Model client1 Train Epoch: 2 [14720/15040 (98%)]	Loss: 0.252733
#
# Test set: Average loss for Global model: 1.8342, Accuracy: 9308/10000 (93%)
